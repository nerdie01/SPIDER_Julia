# %%
include(joinpath(dirname(Base.active_project()), "src", "AutoSpider.jl"))
using .AutoSpider, HDF5

include(joinpath(AutoSpider.FUNCTION_PATH, "VizUtils.jl"))
using .VizUtils

p::Array{Float64} = Float64[]
h5open(joinpath(AutoSpider.HDF5_PATH, "data-RK2.hdf5"), "r") do file
    global p = read(file, "result")["value"]["p"]["value"]
end

VizUtils.quickanim(p, 100)
# Out:
# "quickanim.mp4"

# %%
result::Dict = AutoSpider.auto_spider("data-RK6.hdf5", "mhd_settings.json")
# Out:
# ∂By/∂t - 0.01∂^2By/∂x^2 - 0.01∂^2By/∂y^2 + ∂uBy/∂x - ∂vBx/∂x = 0
# ∂Bx/∂t - 0.01∂^2Bx/∂x^2 - 0.01∂^2Bx/∂y^2 - ∂uBy/∂y + ∂vBx/∂y = 0
# ∂u/∂t + ∂u^2/∂x + ∂uv/∂y - 0.002∂^2u/∂x^2 - 0.002∂^2u/∂y^2 + ∂P/∂x - ∂Bx^2/∂x - ∂BxBy/∂y = 0
# ∂v/∂t + ∂uv/∂x + ∂v^2/∂y - 0.002∂^2v/∂x^2 - 0.002∂^2v/∂y^2 + ∂P/∂y - ∂By^2/∂y - ∂BxBy/∂x = 0
# ∂u/∂x + ∂v/∂y = 0
# Dict{Int64, Dict{String, Any}} with 5 entries:
#   5 => Dict("label"=>["∂u/∂x", "∂v/∂y"], "cs"=>[0.0 0.707107 … -0.707106 -0.707…
#   4 => Dict("label"=>["∂v/∂t", "∂uv/∂x", "∂v^2/∂y", "∂^2v/∂x^2", "∂^2v/∂y^2", "…
#   2 => Dict("label"=>["∂Bx/∂t", "∂^2Bx/∂x^2", "∂^2Bx/∂y^2", "∂uBy/∂y", "∂vBx/∂y…
#   3 => Dict("label"=>["∂u/∂t", "∂u^2/∂x", "∂uv/∂y", "∂^2u/∂x^2", "∂^2u/∂y^2", "…
#   1 => Dict("label"=>["∂By/∂t", "∂^2By/∂x^2", "∂^2By/∂y^2", "∂uBy/∂x", "∂vBx/∂x…
