# %%
include(joinpath(dirname(Base.active_project()), "src", "AutoSpider.jl"))
using .AutoSpider

result::Dict = AutoSpider.auto_spider("mhd_rk4_naive_result.hdf5", "mhd_settings.json")
# Out:
# MethodError: no method matching auto_spider(::String, ::String, ::Type{Missing})
# The function `auto_spider` exists, but no method is defined for this combination of argument types.
#
# Closest candidates are:
#   auto_spider(::AbstractString, ::AbstractString, ::String)
#    @ Main.AutoSpider ~/Documents/Projects/SPIDER_jl/src/AutoSpider.jl:8
#   auto_spider(::AbstractString, ::AbstractString)
#    @ Main.AutoSpider ~/Documents/Projects/SPIDER_jl/src/AutoSpider.jl:8
#
#
# Stacktrace:
#  [1] auto_spider(data_f::String, options_f::String)
#    @ Main.AutoSpider ~/Documents/Projects/SPIDER_jl/src/AutoSpider.jl:9
#  [2] top-level scope
#    @ In[1]:4
#  [3] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489
# WARNING: Detected access to binding `AutoSpider.auto_spider` in a world prior to its definition world.
#   Julia 1.12 has introduced more strict world age semantics for global bindings.
#   !!! This code may malfunction under Revise.
# ...

# %%
for i in eachindex(result)
    println(result[i]["k"])
end
# Out:
# 5
# 8
# 8
# 5
# 2
