# %%
include(joinpath(dirname(Base.active_project()), "src", "AutoSpider.jl"))
using .AutoSpider, HDF5

include(joinpath(AutoSpider.FUNCTION_PATH, "VizUtils.jl"))
using .VizUtils

# %%
AutoSpider.auto_spider("data_spec_jl.hdf5", "compare/settings_default.json")
# Out:
# ∂u/∂x + ∂v/∂y = 0
# 0.991∂By/∂t - 0.018∂^2By/∂x^2 + ∂uBy/∂x - 0.991∂vBx/∂x = 0
# ∂Bx/∂t - 0.019∂^2Bx/∂x^2 - 0.019∂^2Bx/∂y^2 - 0.988∂uBy/∂y + ∂vBx/∂y = 0
# BoundsError: attempt to access 0-element Vector{Int64} at index [0]
#
# Stacktrace:
#  [1] throw_boundserror(A::Vector{Int64}, I::Tuple{Int64})
#    @ Base ./essentials.jl:15
#  [2] getindex
#    @ ./essentials.jl:919 [inlined]
#  [3] report_identified_model(cs::Matrix{Float64}, residuals::Vector{Float64}, scales::Vector{Float64}, labels::Vector{String}, gamma::Float64, hide_coef_tol::Float64)
#    @ Main.AutoSpider.ClassImport.ReportModel ~/Documents/School/Research/SPIDER_Julia/src/functions/ReportModel.jl:9
#  [4] report_identified_model
#    @ ~/Documents/School/Research/SPIDER_Julia/src/functions/ReportModel.jl:7 [inlined]
#  [5] auto_spider(data_f::String, options_f::String)
#    @ Main.AutoSpider ~/Documents/School/Research/SPIDER_Julia/src/AutoSpider.jl:62
#  [6] top-level scope
#    @ In[13]:1
#  [7] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489
