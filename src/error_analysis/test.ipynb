# %%
numbers = [1, 2, 3, 4];
findfirst(x -> x ∈ [2,3], [1,2,3,4])
# Out:
# MethodError: no method matching contains(::Vector{Int64}, ::Int64)
# The function `contains` exists, but no method is defined for this combination of argument types.
#
# Closest candidates are:
#   contains(::Any)
#    @ Base strings/util.jl:197
#   contains(::AbstractString, ::Any)
#    @ Base strings/util.jl:140
#
#
# Stacktrace:
#  [1] (::var"#8#9")(x::Int64)
#    @ Main ./In[6]:2
#  [2] findnext(testf::var"#8#9", A::Vector{Int64}, start::Int64)
#    @ Base ./array.jl:2393
#  [3] findfirst(testf::Function, A::Vector{Int64})
#    @ Base ./array.jl:2444
#  [4] top-level scope
#    @ In[6]:2
#  [5] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489
